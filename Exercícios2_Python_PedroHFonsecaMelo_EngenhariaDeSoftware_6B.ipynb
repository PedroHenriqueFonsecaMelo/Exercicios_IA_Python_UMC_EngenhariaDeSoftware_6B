# %% [markdown]
# 1. Calculadora de Médias
# Enunciado: Crie um programa que calcule a média aritmética de uma lista de números fornecida pelo usuário. O programa deve permitir que o usuário insira quantos números desejar e, ao final, exibir a média dos números inseridos.

# %%
entrada = input("Digite os números separados por espaço: ")

array = []

for item in entrada.split():
    array.append(int(item))


print("Média final:", (sum(array)/len(array)))
# Out:
# Digite os números separados por espaço: 21 45
# Média final: 33.0

# %% [markdown]
# 2. Contador de Caracteres
# Enunciado: Desenvolva um script que conte quantas vezes cada caractere aparece em uma string fornecida pelo usuário. O programa deve ignorar espaços e diferenciar maiúsculas de minúsculas.

# %%
texto = input("Digite um texto: ")

contador = {}

for caractere in texto:
    if caractere != " ":
        if caractere in contador:
            contador[caractere] += 1
        else:
            contador[caractere] = 1

print("\nFrequência dos caracteres:")
for chave, valor in contador.items():
    print(f"'{chave}': {valor}")

# %% [markdown]
# 3. Verificador de Palíndromo
# Enunciado: Escreva um programa que verifique se uma palavra ou frase (ignorando espaços e pontuações) é um palíndromo, ou seja, se ela é igual quando lida de trás para frente.

# %%
def palindromo(string):
    size = len(string)
    if size == 0:
        return "Não é Palíndromo"
    for i in range(0, size // 2):
        if string[i] != string[size - i - 1]:
            return "Não é Palíndromo"
    return "é Palíndromo"
palindromo(input("Digite para validar o Palíndromo : "))

# %% [markdown]
# 4. Conversor de Temperatura
# Enunciado: Crie um conversor que transforme temperaturas de Celsius para Fahrenheit e vice-versa. O programa deve permitir que o usuário escolha o tipo de conversão e insira a temperatura.

# %%
print("Escolha a conversão:")
print("[1] Celsius para Fahrenheit")
print("[2] Fahrenheit para Celsius")

opcao = input("Digite 1 ou 2: ")

if opcao == "1":
    celsius = float(input("Digite a temperatura em Celsius: "))
    fahrenheit = (celsius * 9/5) + 32
    print(f"{celsius}°C equivale a {fahrenheit}°F")

elif opcao == "2":
    fahrenheit = float(input("Digite a temperatura em Fahrenheit: "))
    celsius = (fahrenheit - 32) * 5/9
    print(f"{fahrenheit}°F equivale a {celsius}°C")

else:
    print("Opção inválida!")

# %% [markdown]
# 5. Gerador de Tabuada
# Enunciado: Desenvolva um programa que gere a tabuada de um número fornecido pelo usuário. O programa deve exibir a multiplicação de 1 até 10 para o número informado.

# %%
def Tabuada(N_tabuada):
    for i in range (1,10):
        print(i*N_tabuada)

Tabuada(int(input("Digite o número para tabuada: ")))

# %% [markdown]
# 6. Simulador de Lançamento de Dados
# Enunciado: Escreva um script que simule o lançamento de um dado de 6 faces. O programa deve solicitar ao usuário quantas vezes ele deseja lançar o dado e mostrar os resultados de cada lançamento.

# %%
import time

quantidade = int(input("Quantas vezes deseja lançar o dado? "))

resultados = []

for _ in range(quantidade):
    time.sleep(0.1)
    tempo_atual = time.time()
    milissegundos = int((tempo_atual - int(tempo_atual)) * 1000)
    dado = (milissegundos % 6) + 1
    resultados.append(dado)

print("\nResultados dos lançamentos:", resultados)

# %% [markdown]
# 7. Ordenação de Lista
# Enunciado: Desenvolva um programa que receba uma lista de números do usuário e ordene essa lista em ordem crescente. O programa deve exibir a lista antes e depois da ordenação.

# %%
entrada = input("Digite números separados por espaço: ")

numeros = []

for item in entrada.split():
    numeros.append(int(item))

print("\nLista antes da ordenação:", numeros)

for i in range(len(numeros)):
    for j in range(i + 1, len(numeros)):
        if numeros[i] > numeros[j]:
            numeros[i], numeros[j] = numeros[j], numeros[i]

print("Lista ordenada:", numeros)

# %% [markdown]
# 8. Verificador de Números Primos
# Enunciado: Crie um programa que determine se um número fornecido pelo usuário é primo. O programa deve informar se o número é primo ou não e listar todos os divisores do número.

# %%
def Primo (num):
    if num > 1:
        for i in range(2, (num//2)+1):
            if (num % i) == 0:
                print(num, "não é primo")
                break
        else:
            print(num, "é primo")
    else:
        print(num, "não é primo")
Primo (int(input("Digite o número para ver se é primo: ")))

# %% [markdown]
# 9. Sistema de Login Simples
# Enunciado: Implemente um sistema de login simples que armazene os nomes de usuário e senhas em um dicionário. O programa deve permitir que o usuário se cadastre e faça login, validando as credenciais inseridas.

# %%
# Dicionário para armazenar usuários e senhas
usuarios = {}

while True:
    print("\n1. Cadastrar\n2. Login\n3. Sair")
    opcao = input("Escolha uma opção: ").strip()

    if opcao == "1":
        usuario = input("Nome de usuário: ").strip()
        senha = input("Senha: ").strip()
        if usuario in usuarios:
            print("Usuário já existe!")
        else:
            usuarios[usuario] = senha  # Armazena usuário e senha no dicionário
            print("Cadastro realizado com sucesso!")

    elif opcao == "2":
        usuario = input("Nome de usuário: ").strip()
        senha = input("Senha: ").strip()
        if usuario in usuarios and usuarios[usuario] == senha:
            print("Login bem-sucedido!")
        else:
            print("Usuário ou senha incorretos.")

    elif opcao == "3":
        break  # Sai do loop

    else:
        print("Opção inválida! Escolha novamente.")
# Out:
# 1. Cadastrar
# 2. Login
# 3. Sair
# Escolha uma opção: 1
# Nome de usuário: ppp
# Senha: 555
# Cadastro realizado com sucesso!
#
# 1. Cadastrar
# 2. Login
# 3. Sair
# Escolha uma opção: 2
# Nome de usuário: ppp
# Senha: 555
# Login bem-sucedido!
#
# 1. Cadastrar
# 2. Login
# 3. Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-816d9dbdd2ee> in <cell line: 0>()
#       4 while True:
#       5     print("\n1. Cadastrar\n2. Login\n3. Sair")
# ----> 6     opcao = input("Escolha uma opção: ").strip()
#       7
#       8     if opcao == "1":
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# 10. Calculadora de Fatorial
# Enunciado: Escreva um programa que calcule o fatorial de um número fornecido pelo usuário utilizando um loop for. O programa deve exibir o resultado do fatorial ao final.

# %%
def fatorial(n):
    fatorial = 1
    for i in range(1, n + 1):
        fatorial *= i
    return fatorial

print(fatorial(int(input("Entre o numero para fatorial: "))))
# Out:
# Entre o numero para fatorial: 25
# 15511210043330985984000000

# %% [markdown]
# 11. Conversor de Moedas Simples
# Enunciado: Crie um programa que converta um valor em reais para dólares ou euros. O programa deve permitir que o usuário escolha a moeda de destino e insira o valor a ser convertido, utilizando uma taxa de câmbio fixa definida no código.

# %%
taxa_dolar = 5.0
taxa_euro = 5.5

valor_reais = float(input("Digite o valor em reais (R$): "))
opcao = input("Converter para (D)ólar ou (E)uro? ").strip().lower()

if opcao == 'd':
    convertido = valor_reais / taxa_dolar
    print(f"R$ {valor_reais:.2f} equivale a US$ {convertido:.2f}")
elif opcao == 'e':
    convertido = valor_reais / taxa_euro
    print(f"R$ {valor_reais:.2f} equivale a € {convertido:.2f}")
else:
    print("Opção inválida.")
# Out:
# Digite o valor em reais (R$): 5
# Converter para (D)ólar ou (E)uro? D
# R$ 5.00 equivale a US$ 1.00

# %% [markdown]
# 12. Contador de Palavras
# Enunciado: Desenvolva um script que conte o número de palavras em uma frase fornecida pelo usuário. O programa deve ignorar pontuações e considerar apenas as palavras separadas por espaços.

# %%
# Solicita uma frase ao usuário
frase = input("Digite uma frase: ").strip()

# Inicializa variáveis
palavras = []
palavra_atual = ""

# Percorre a frase caractere por caractere
for caractere in frase:
    if not ("0" <= caractere <= "9"):  # Verifica se NÃO é um número
        if caractere != " ":  # Se não for espaço, adiciona à palavra atual
            palavra_atual += caractere
        else:
            if palavra_atual:  # Se já temos uma palavra formada, adicionamos à lista
                palavras.append(palavra_atual)
                palavra_atual = ""  # Reseta a palavra atual

# Adiciona a última palavra caso exista
if palavra_atual:
    palavras.append(palavra_atual)

# Conta as palavras manualmente
contador = 0
for _ in palavras:
    contador += 1

# Exibe o número total de palavras
print(f"Número de palavras: {contador}")

# %% [markdown]
# 13. Gerador de Números Aleatórios
# Enunciado: Escreva um programa que gere n números aleatórios entre um intervalo fornecido pelo usuário. O programa deve solicitar o valor de n e os limites inferior e superior do intervalo.

# %%
import time

quantidade = int(input("Quantos números aleatórios deseja gerar? "))
limite_inferior = int(input("Digite o menor valor: "))
limite_superior = int(input("Digite o maior valor: "))

numeros = []

for _ in range(quantidade):
    time.sleep(0.1)  # Pequeno atraso
    milissegundos = int((time.time() - int(time.time())) * 100000)
    numero = (milissegundos % (limite_superior - limite_inferior + 1)) + limite_inferior
    numeros.append(numero)

print("Números gerados:", numeros)
# Out:
# Quantos números aleatórios deseja gerar? 5
# Digite o menor valor: 200
# Digite o maior valor: 1
# Números gerados: [36, 152, 72, 183, 102]

# %% [markdown]
# 14. Calculadora de Média Ponderada
# Enunciado: Implemente uma calculadora que permita ao usuário calcular a média ponderada de um conjunto de notas. O usuário deve inserir as notas e os respectivos pesos, e o programa deve calcular e exibir a média ponderada.

# %%
entrada = input("Digite os números separados por espaço: ")
soma_pesos = 0
soma_ponderada = 0


for item in entrada.split():
    nota = float(item)
    peso = float(input("Digite o peso: "))
    soma_pesos += peso
    soma_ponderada += nota * peso


print("Média final:", soma_ponderada / soma_pesos)
# Out:
# Digite os números separados por espaço: 20 12 25
# Digite o peso: 1
# Digite o peso: 2
# Digite o peso: 0.1
# Média final: 15.0

# %% [markdown]
# 15. Cálculo de Raiz Quadrada
# Enunciado: Desenvolva um programa que calcule a raiz quadrada de um número fornecido pelo usuário. Utilize a função sqrt() do módulo math e exiba o resultado.

# %%
import math

numero = float(input("Digite um número para calcular a raiz quadrada: "))

# Cálculo manual usando a exponenciação
raiz_quadrada = math.sqrt(numero)

print(f"A raiz quadrada de {numero} é {raiz_quadrada:.2f}")
# Out:
# Digite um número para calcular a raiz quadrada: 25
# A raiz quadrada de 25.0 é 5.00

# %% [markdown]
# 16. Simulador de Caixa Eletrônico
# Enunciado: Crie um programa que simule um caixa eletrônico. O usuário deve inserir o valor que deseja sacar, e o programa deve exibir quantas notas de cada valor serão entregues (R$100, R$50, R$20, R$10).

# %%
notas = [100, 50, 20, 10]

valor = int(input("Digite o valor do saque: "))

# Cálculo manual das notas
for nota in notas:
    if valor >= nota:
        quantidade = valor // nota
        valor %= nota
        print(f"{quantidade} nota(s) de R$ {nota}")
# Out:
# Digite o valor do saque: 1252
# 12 nota(s) de R$ 100
# 1 nota(s) de R$ 50

# %% [markdown]
# 17. Verificador de Ano Bissexto
# Enunciado: Escreva um programa que determine se um ano fornecido pelo usuário é bissexto. O programa deve seguir as regras para anos bissextos (divisíveis por 4, exceto se divisíveis por 100, mas divisíveis por 400).

# %%
ano = int(input("Digite um ano para verificar se é bissexto: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f"{ano} é um ano bissexto.")
else:
    print(f"{ano} não é um ano bissexto.")
# Out:
# Digite um ano para verificar se é bissexto: 2000
# 2000 é um ano bissexto.

# %% [markdown]
# 18. Gerenciador de Contatos Simples
# Enunciado: Desenvolva um sistema simples para gerenciar contatos, onde o usuário pode adicionar, remover e listar contatos (nome e telefone). Utilize um dicionário para armazenar os contatos.

# %%
# Dicionário para armazenar os contatos
contatos = {}

while True:
    print("\n1. Adicionar Contato\n2. Remover Contato\n3. Listar Contatos\n4. Sair")
    opcao = input("Escolha uma opção: ").strip()

    if opcao == "1":
        nome = input("Nome: ").strip()
        telefone = input("Telefone: ").strip()
        contatos[nome] = telefone  # Adiciona contato ao dicionário
        print(f"Contato {nome} adicionado!")

    elif opcao == "2":
        nome = input("Nome do contato a remover: ").strip()
        if nome in contatos:
            del contatos[nome]  # Remove o contato do dicionário
            print(f"Contato {nome} removido!")
        else:
            print("Contato não encontrado.")

    elif opcao == "3":
        if contatos:
            for nome, telefone in contatos.items():
                print(f"{nome}: {telefone}")  # Exibe todos os contatos
        else:
            print("Nenhum contato cadastrado.")

    elif opcao == "4":
        break  # Sai do loop

    else:
        print("Opção inválida! Escolha novamente.")
# Out:
# 1. Adicionar Contato
# 2. Remover Contato
# 3. Listar Contatos
# 4. Sair
# Escolha uma opção: 1
# Nome: aaa
# Telefone: 1222
# Contato aaa adicionado!
#
# 1. Adicionar Contato
# 2. Remover Contato
# 3. Listar Contatos
# 4. Sair
# Escolha uma opção: 3
# aaa: 1222
#
# 1. Adicionar Contato
# 2. Remover Contato
# 3. Listar Contatos
# 4. Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-53560bb87b83> in <cell line: 0>()
#       4 while True:
#       5     print("\n1. Adicionar Contato\n2. Remover Contato\n3. Listar Contatos\n4. Sair")
# ----> 6     opcao = input("Escolha uma opção: ").strip()
#       7
#       8     if opcao == "1":
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# 19. Calculadora de Desconto
# Enunciado: Crie um programa que calcule o preço final de um produto após a aplicação de um desconto. O usuário deve inserir o preço original e a porcentagem de desconto, e o programa deve exibir o preço final.

# %%
preco_original = float(input("Digite o preço do produto: "))
desconto = float(input("Digite o percentual de desconto: "))

preco_final = preco_original * (1 - desconto / 100)

print(f"Preço final com desconto: R$ {preco_final:.2f}")

# %% [markdown]
# 20. Análise de Dados Simples com Pandas e Matplotlib
# Enunciado: Utilize o Pandas para carregar um dataset simples, como o conjunto de dados do Titanic ou Iris, disponível na biblioteca seaborn. Realize uma análise básica para calcular estatísticas descritivas, como média e mediana de colunas numéricas. Em seguida, utilize o Matplotlib para criar gráficos simples (como histogramas ou gráficos de barras) que visualizem algumas dessas estatísticas ou distribuições.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("titanic")

print(df.describe())

# Criar gráfico
df["age"].hist(bins=20)
plt.title("Distribuição de Idades no Titanic")
plt.xlabel("Idade")
plt.ylabel("Frequência")
plt.show()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
